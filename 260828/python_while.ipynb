# %%
# 시중에 교보문고 : git & github 검색.조회
# (지옥에서 온) git & github -> 멘탈 // 고민
# git commit & push 관리 AI (간단한 에러는 거의 나오지 않음)

# %%
# 기초 함수 정의하기

def addfnc(num01, num02) :
    return num01 + num02
    print(num01 + num02)

# %%
sumtotal = addfnc(1, 2)

# %%
print(sumtotal)
# Out:
# 3

# %% [markdown]
# 1. 파이썬 기본구문
# - 변수, 자료형 > int, float => 정수, 실수자료형 => 수치형 데이터
# - 연산자 : 산술연산자 (사칙연산자 + @), 비교연산자
# - 문자열
# - 리스트
# - ----
# - [제어문]
# - 조건문 : 조건식 (논리연산자 / and, or, not),
# - 반복문 : 복합대입 연산자
# - sum = sum + 1 => sum += 1

# %%
for i in range(10) :
    print(i * i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
data_list = ["list1", "list2", "list3"] # 리스트 자료구조 의미 : [], list()

# %%
type(data_list) # list 자료구조 => 세부적인 값 => index 정의 => 반복문 사용
# Out:
# list

# %%
for index in data_list :
    print(index)
# Out:
# list1
# list2
# list3

# %%
sum = 0

for i in range(1, 11) :
    sum += i

print(sum)
# Out:
# 55

# %%
# 반복해야할 대상 결정, 반복횟수 결정 -> for 문
# 언제까지 반복될지는 장담불가 -> while 문
# += / -= / *= / /=

i = 0
while i <= 3 :
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3

# %%
name = ""

while name != "David" :
    name = input("What is your name?")
    # print(f"Hi {name}, where is David?")
    print("Hi " + name + " where is David?")
# Out:
# What is your name? Dave
# Hi Dave where is David?
# What is your name? Jane
# Hi Jane where is David?
# What is your name? David
# Hi David where is David?

# %%
# 연습문제!!!

# %%
data = int(input("구구단 몇 단을 제작하시겠습니까? ex. 2단 -> 2 :"))
# 조건 : 2~9단 까지만 구구단을 생성해라! 10~ x
for digit in range(1, 10) :
    print(f"{data} x {digit} = {data * digit}")
# Out:
# 구구단 몇 단을 제작하시겠습니까? ex. 2단 -> 2 : 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18

# %%
data = int(input("구구단 몇 단을 제작하시겠습니까? ex. 2단 -> 2 :"))
# 조건 : 2~9단 까지만 구구단을 생성해라! 10~ x
if data >= 2 and data <= 9 :
    for digit in range(1, 10) :
        print(f"{data} x {digit} = {data * digit}")
else :
    print("실행할 수 없습니다!")
# Out:
# 구구단 몇 단을 제작하시겠습니까? ex. 2단 -> 2 : 12
# 실행할 수 없습니다!

# %%
data = "[Dave],[David],[Andy],[Arthor]"

# %%
type(data)
len(data)
# Out:
# 30

# %%
# str => list (split => 인자값으로 구분자를 입력, 해당 구분자 기준 각각의 값을 나눠서 관리 => 리스트)
for str_data in data.split(",") :
    print(str_data[1:-1])
# Out:
# Dave
# David
# Andy
# Arthor

# %%
num = 0

while num < 30 :
    num += 1
    if num % 3 == 0 :
        print(num)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
